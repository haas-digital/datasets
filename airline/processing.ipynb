# %%
import pandas as pd
import numpy as np
# Out:
# /Users/split/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
df = pd.read_csv('2021jan.csv')

# %%
df = df.drop(['QUARTER', 'BRANDED_CODE_SHARE'], axis=1)
df
# Out:
#         YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE MKT_UNIQUE_CARRIER  \
# 0       2021      1             5            2  2021-01-05                 DL
# 1       2021      1             5            2  2021-01-05                 DL
# 2       2021      1             5            2  2021-01-05                 DL
# 3       2021      1             5            2  2021-01-05                 DL
# 4       2021      1             5            2  2021-01-05                 DL
# ...      ...    ...           ...          ...         ...                ...
# 379379  2021      1            15            5  2021-01-15                 AA
# 379380  2021      1            16            6  2021-01-16                 AA
# 379381  2021      1            17            7  2021-01-17                 AA
# 379382  2021      1            18            1  2021-01-18                 AA
# 379383  2021      1            19            2  2021-01-19                 AA
#
# ...

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'MKT_UNIQUE_CARRIER', 'OP_UNIQUE_CARRIER', 'ORIGIN_AIRPORT_ID',
#        'ORIGIN_AIRPORT_SEQ_ID', 'ORIGIN_CITY_MARKET_ID', 'DEST_AIRPORT_ID',
#        'DEST_AIRPORT_SEQ_ID', 'DEST_CITY_MARKET_ID', 'CRS_DEP_TIME',
#        'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW', 'DEP_DEL15',
#        'DEP_DELAY_GROUP', 'CRS_ARR_TIME', 'ARR_TIME', 'ARR_DELAY',
#        'ARR_DELAY_NEW', 'ARR_DEL15', 'CANCELLED', 'DIVERTED', 'DISTANCE_GROUP',
#        'Unnamed: 29'],
#       dtype='object')
